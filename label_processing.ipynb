# %%
import pandas as pd
import re
import transformers as ppb
import numpy as np
from scipy import sparse

# %%
DATA_DIR = "./data"
admissions_file = DATA_DIR + '/ADMISSIONS.csv'

# %%
full_admissions = pd.read_csv(admissions_file)
print(full_admissions.shape)
print(full_admissions.dtypes)
full_admissions.head()
# Out:
# (58976, 19)
# ROW_ID                   int64
# SUBJECT_ID               int64
# HADM_ID                  int64
# ADMITTIME               object
# DISCHTIME               object
# DEATHTIME               object
# ADMISSION_TYPE          object
# ADMISSION_LOCATION      object
# DISCHARGE_LOCATION      object
# INSURANCE               object
# LANGUAGE                object
# RELIGION                object
# MARITAL_STATUS          object
# ETHNICITY               object
# EDREGTIME               object
# EDOUTTIME               object
# DIAGNOSIS               object
# HOSPITAL_EXPIRE_FLAG     int64
# HAS_CHARTEVENTS_DATA     int64
# dtype: object
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1      22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2      23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3      24          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4      25          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
#
#   DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 0       NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 1       NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 2       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 3       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 4       NaN      EMERGENCY       EMERGENCY ROOM ADMIT
#
#           DISCHARGE_LOCATION INSURANCE LANGUAGE           RELIGION  \
# 0  DISC-TRAN CANCER/CHLDRN H   Private      NaN       UNOBTAINABLE
# 1           HOME HEALTH CARE  Medicare      NaN           CATHOLIC
# 2           HOME HEALTH CARE  Medicare     ENGL           CATHOLIC
# 3                       HOME   Private      NaN  PROTESTANT QUAKER
# 4                       HOME   Private      NaN       UNOBTAINABLE
#
#   MARITAL_STATUS ETHNICITY            EDREGTIME            EDOUTTIME  \
# 0        MARRIED     WHITE  2196-04-09 10:06:00  2196-04-09 13:24:00
# 1        MARRIED     WHITE                  NaN                  NaN
# 2        MARRIED     WHITE                  NaN                  NaN
# 3         SINGLE     WHITE                  NaN                  NaN
# 4        MARRIED     WHITE  2160-11-02 01:01:00  2160-11-02 04:27:00
#
#                                            DIAGNOSIS  HOSPITAL_EXPIRE_FLAG  \
# 0                            BENZODIAZEPINE OVERDOSE                     0
# 1  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 2                                         BRAIN MASS                     0
# 3                     INTERIOR MYOCARDIAL INFARCTION                     0
# 4                            ACUTE CORONARY SYNDROME                     0
#
#    HAS_CHARTEVENTS_DATA
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
full_admissions['ADMITTIME'] = pd.to_datetime(full_admissions['ADMITTIME'])
full_admissions['DISCHTIME'] = pd.to_datetime(full_admissions['DISCHTIME'])
full_admissions['DEATHTIME'] = pd.to_datetime(full_admissions['DEATHTIME'])
full_admissions.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID           ADMITTIME           DISCHTIME  \
# 0      21          22   165315 2196-04-09 12:26:00 2196-04-10 15:54:00
# 1      22          23   152223 2153-09-03 07:15:00 2153-09-08 19:10:00
# 2      23          23   124321 2157-10-18 19:34:00 2157-10-25 14:00:00
# 3      24          24   161859 2139-06-06 16:14:00 2139-06-09 12:48:00
# 4      25          25   129635 2160-11-02 02:06:00 2160-11-05 14:55:00
#
#   DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 0       NaT      EMERGENCY       EMERGENCY ROOM ADMIT
# 1       NaT       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 2       NaT      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 3       NaT      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 4       NaT      EMERGENCY       EMERGENCY ROOM ADMIT
#
#           DISCHARGE_LOCATION INSURANCE LANGUAGE           RELIGION  \
# 0  DISC-TRAN CANCER/CHLDRN H   Private      NaN       UNOBTAINABLE
# 1           HOME HEALTH CARE  Medicare      NaN           CATHOLIC
# 2           HOME HEALTH CARE  Medicare     ENGL           CATHOLIC
# 3                       HOME   Private      NaN  PROTESTANT QUAKER
# 4                       HOME   Private      NaN       UNOBTAINABLE
#
#   MARITAL_STATUS ETHNICITY            EDREGTIME            EDOUTTIME  \
# 0        MARRIED     WHITE  2196-04-09 10:06:00  2196-04-09 13:24:00
# 1        MARRIED     WHITE                  NaN                  NaN
# 2        MARRIED     WHITE                  NaN                  NaN
# 3         SINGLE     WHITE                  NaN                  NaN
# 4        MARRIED     WHITE  2160-11-02 01:01:00  2160-11-02 04:27:00
#
#                                            DIAGNOSIS  HOSPITAL_EXPIRE_FLAG  \
# 0                            BENZODIAZEPINE OVERDOSE                     0
# 1  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 2                                         BRAIN MASS                     0
# 3                     INTERIOR MYOCARDIAL INFARCTION                     0
# 4                            ACUTE CORONARY SYNDROME                     0
#
#    HAS_CHARTEVENTS_DATA
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
admits_patient_df = full_admissions.sort_values(by=['SUBJECT_ID','DISCHTIME']).loc[:,('ROW_ID','SUBJECT_ID','HADM_ID','ADMITTIME',\
    'DISCHTIME','DEATHTIME','ADMISSION_TYPE','DIAGNOSIS','HOSPITAL_EXPIRE_FLAG','HAS_CHARTEVENTS_DATA')]
admits_patient_df.head()
# Out:
#      ROW_ID  SUBJECT_ID  HADM_ID           ADMITTIME           DISCHTIME  \
# 211       1           2   163353 2138-07-17 19:04:00 2138-07-21 15:48:00
# 212       2           3   145834 2101-10-20 19:08:00 2101-10-31 13:58:00
# 213       3           4   185777 2191-03-16 00:28:00 2191-03-23 18:41:00
# 214       4           5   178980 2103-02-02 04:31:00 2103-02-04 12:15:00
# 215       5           6   107064 2175-05-30 07:15:00 2175-06-15 16:00:00
#
#     DEATHTIME ADMISSION_TYPE                            DIAGNOSIS  \
# 211       NaT        NEWBORN                              NEWBORN
# 212       NaT      EMERGENCY                          HYPOTENSION
# 213       NaT      EMERGENCY  FEVER,DEHYDRATION,FAILURE TO THRIVE
# 214       NaT        NEWBORN                              NEWBORN
# 215       NaT       ELECTIVE            CHRONIC RENAL FAILURE/SDA
#
#      HOSPITAL_EXPIRE_FLAG  HAS_CHARTEVENTS_DATA
# 211                     0                     1
# 212                     0                     1
# 213                     0                     1
# 214                     0                     1
# 215                     0                     1

# %%
mult_admits = admits_patient_df[admits_patient_df.duplicated(subset=['SUBJECT_ID'],keep=False)]
mult_admits.head(15)
# Out:
#      ROW_ID  SUBJECT_ID  HADM_ID           ADMITTIME           DISCHTIME  \
# 224      14          17   194023 2134-12-27 07:15:00 2134-12-31 16:05:00
# 225      15          17   161087 2135-05-09 14:11:00 2135-05-13 14:40:00
# 229      19          21   109451 2134-09-11 12:17:00 2134-09-24 16:15:00
# 230      20          21   111970 2135-01-30 20:50:00 2135-02-08 02:08:00
# 1        22          23   152223 2153-09-03 07:15:00 2153-09-08 19:10:00
# 2        23          23   124321 2157-10-18 19:34:00 2157-10-25 14:00:00
# 12       33          34   115799 2186-07-18 16:46:00 2186-07-20 16:00:00
# 13       34          34   144319 2191-02-23 05:23:00 2191-02-25 20:20:00
# 15       36          36   182104 2131-04-30 07:15:00 2131-05-08 14:00:00
# 16       37          36   122659 2131-05-12 19:49:00 2131-05-25 13:30:00
# 17       38          36   165660 2134-05-10 11:30:00 2134-05-20 13:16:00
# 62       60          61   176332 2118-06-17 14:40:00 2118-07-20 12:30:00
# 63       61          61   189535 2119-01-04 18:12:00 2119-02-03 01:35:00
# 69       67          67   186474 2155-02-25 12:45:00 2155-03-06 15:00:00
# 70       68          67   155252 2157-12-02 00:45:00 2157-12-02 03:55:00
#
#               DEATHTIME ADMISSION_TYPE  \
# 224                 NaT       ELECTIVE
# 225                 NaT      EMERGENCY
# 229                 NaT      EMERGENCY
# 230 2135-02-08 02:08:00      EMERGENCY
# 1                   NaT       ELECTIVE
# 2                   NaT      EMERGENCY
# 12                  NaT      EMERGENCY
# 13                  NaT      EMERGENCY
# 15                  NaT      EMERGENCY
# 16                  NaT      EMERGENCY
# 17                  NaT       ELECTIVE
# 62                  NaT       ELECTIVE
# 63  2119-02-03 01:35:00      EMERGENCY
# 69                  NaT         URGENT
# 70  2157-12-02 03:55:00      EMERGENCY
#
#                                              DIAGNOSIS  HOSPITAL_EXPIRE_FLAG  \
# 224  PATIENT FORAMEN OVALE\ PATENT FORAMEN OVALE MI...                     0
# 225                               PERICARDIAL EFFUSION                     0
# 229                           CONGESTIVE HEART FAILURE                     0
# 230                                             SEPSIS                     1
# 1    CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 2                                           BRAIN MASS                     0
# 12                                     CHEST PAIN\CATH                     0
# 13                                         BRADYCARDIA                     0
# 15   CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 16                      CHEST PAIN/SHORTNESS OF BREATH                     0
# 17                                  VENTRAL HERNIA/SDA                     0
# 62      NON-HODGKIN'S LYMPHOMIA\BONE MARROW TRANSPLANT                     0
# 63           NON-HODGKINS LYMPHOMA;FEBRILE;NEUTROPENIA                     1
# 69                                   INCISIONAL HERNIA                     0
# 70                             SUBARACHNOID HEMORRHAGE                     1
#
#      HAS_CHARTEVENTS_DATA
# 224                     1
# 225                     1
# 229                     1
# 230                     1
# 1                       1
# 2                       1
# 12                      1
# 13                      1
# 15                      1
# 16                      1
# 17                      1
# 62                      1
# 63                      1
# 69                      0
# 70                      1

# %%
mult_admits[mult_admits['SUBJECT_ID']==36].loc[:,('DISCHTIME','READMIT')].rolling(window='30D', on='DISCHTIME',closed='left').sum()
# Out:
#              DISCHTIME  READMIT
# 15 2131-05-08 14:00:00      NaN
# 16 2131-05-25 13:30:00      1.0
# 17 2134-05-20 13:16:00      NaN

# %%
subjects = mult_admits['SUBJECT_ID'].unique()
mult_admits.loc[:,'READMIT'] = 1

# identify re-admits within 30 days
for subject in subjects:
    readmitted = mult_admits[mult_admits['SUBJECT_ID'] == subject].loc[:,('DISCHTIME','READMIT')].rolling(window='30D', on='DISCHTIME',closed='left').sum()
    #print(readmitted)
    mult_admits.loc[readmitted.index, 'READMIT'] = readmitted['READMIT']
    #print(subject)

mult_admits['READMIT_2'] = mult_admits['READMIT'].shift(-1)
# Out:
# /home/npodpx/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# /home/npodpx/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /tmp/ipykernel_23941/3362247210.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mult_admits['READMIT_2'] = mult_admits['READMIT'].shift(-1)

# %%
mult_admits[mult_admits['SUBJECT_ID'] == 36]
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID           ADMITTIME           DISCHTIME  \
# 15      36          36   182104 2131-04-30 07:15:00 2131-05-08 14:00:00
# 16      37          36   122659 2131-05-12 19:49:00 2131-05-25 13:30:00
# 17      38          36   165660 2134-05-10 11:30:00 2134-05-20 13:16:00
#
#    DEATHTIME ADMISSION_TYPE  \
# 15       NaT      EMERGENCY
# 16       NaT      EMERGENCY
# 17       NaT       ELECTIVE
#
#                                             DIAGNOSIS  HOSPITAL_EXPIRE_FLAG  \
# 15  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 16                     CHEST PAIN/SHORTNESS OF BREATH                     0
# 17                                 VENTRAL HERNIA/SDA                     0
#
#     HAS_CHARTEVENTS_DATA  READMIT  READMIT_2
# 15                     1      NaN        1.0
# 16                     1      1.0        NaN
# 17                     1      NaN        NaN
